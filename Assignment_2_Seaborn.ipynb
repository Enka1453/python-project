# %% [markdown]
# <a href="https://colab.research.google.com/github/Enka1453/python-project/blob/main/Assignment_2_Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # WITH SEABORN

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# INSTRUCTIONS
# 1. Box and Swarm Plots in kill data
# 1. Most dangerous cities
# 1. Most dangerous states
# 1. Having mental ilness or not for killed people
# 1. Threat types
# 1. Flee types
# <br>

# %%
kill = pd.read_csv('PoliceKillingsUS.csv', encoding="windows-1252")

# %%
kill.head()
# Out:
#    id                name      date  ... threat_level         flee  body_camera
# 0   3          Tim Elliot  02/01/15  ...       attack  Not fleeing        False
# 1   4    Lewis Lee Lembke  02/01/15  ...       attack  Not fleeing        False
# 2   5  John Paul Quintero  03/01/15  ...        other  Not fleeing        False
# 3   8     Matthew Hoffman  04/01/15  ...       attack  Not fleeing        False
# 4   9   Michael Rodriguez  04/01/15  ...       attack  Not fleeing        False
#
# [5 rows x 14 columns]

# %%
kill.shape
# Out:
# (2535, 14)

# %% [markdown]
# ## 1a: Box plot of age in both genders separeted by manner of death.

# %%
kill.head()
# Out:
#    id                name      date  ... threat_level         flee  body_camera
# 0   3          Tim Elliot  02/01/15  ...       attack  Not fleeing        False
# 1   4    Lewis Lee Lembke  02/01/15  ...       attack  Not fleeing        False
# 2   5  John Paul Quintero  03/01/15  ...        other  Not fleeing        False
# 3   8     Matthew Hoffman  04/01/15  ...       attack  Not fleeing        False
# 4   9   Michael Rodriguez  04/01/15  ...       attack  Not fleeing        False
#
# [5 rows x 14 columns]

# %%
kill.manner_of_death.unique()
# Out:
# array(['shot', 'shot and Tasered'], dtype=object)

# %% [markdown]
# **INSTRUCTION: Demonstrate the Qurtiles of age in both genders separeted by manner of death.**

# %%
sns.boxplot(x="gender",y="age", hue="manner_of_death",data=kill);

# %% [markdown]
# ## 1b: Swarm Plot

# %% [markdown]
# **INSTRUCTION: Demonstrate the age in both genders separeted by manner of death by a swarm plot.**

# %%
plt.figure(figsize=(10,6))
sns.swarmplot(x="gender",y="age", hue="manner_of_death",data=kill);

# %% [markdown]
# ## 2: Plot 12 most dangerous cities

# %%
city_freq = kill.groupby("city")["threat_level"].count().sort_values(ascending=False).head(12)
city_freq
# Out:
# city
# Los Angeles     39
# Phoenix         31
# Houston         27
# Chicago         25
# Las Vegas       21
# San Antonio     20
# Columbus        19
# Miami           18
# Austin          18
# St. Louis       15
# Albuquerque     14
# Indianapolis    14
# Name: threat_level, dtype: int64

# %%
fig, ax =plt.subplots(figsize=(8,5))
sns.barplot(x=city_freq.index,y=city_freq)
ax.set_title("Most dangerous cities", color="blue", size=15)
plt.xticks(rotation=45);

# %% [markdown]
# ## 3: Plot 20 most dangerous states

# %%
state_freq = kill.groupby("state")["threat_level"].count().sort_values(ascending=False).head(20)
state_freq
# Out:
# state
# CA    424
# TX    225
# FL    154
# AZ    118
# OH     79
# OK     78
# CO     74
# GA     70
# NC     69
# MO     64
# IL     62
# WA     62
# TN     59
# LA     57
# NM     51
# PA     51
# AL     50
# VA     47
# NY     45
# SC     44
# Name: threat_level, dtype: int64

# %%
fig, ax =plt.subplots(figsize=(8,5))
sns.barplot(x=state_freq.index,y=state_freq)
ax.set_title("Most dangerous states", color="blue", size=15)
plt.xticks(rotation=45);

# %% [markdown]
# ## 4: Plot Having mental ilness or not for killed people

# %%
illness = kill.signs_of_mental_illness.value_counts()
illness
# Out:
# False    1902
# True      633
# Name: signs_of_mental_illness, dtype: int64

# %%
sns.barplot(x=illness.index, y=illness);

# %% [markdown]
# ## 5: Plot number of Threat Types

# %%
threads_freq = kill.threat_level.value_counts()
threads_freq
# Out:
# attack          1611
# other            766
# undetermined     158
# Name: threat_level, dtype: int64

# %%
sns.barplot(x=threads_freq.index, y=threads_freq);

# %% [markdown]
# ## 6: Plot number of Flee Types

# %%
flee_freq = kill.flee.value_counts()
flee_freq
# Out:
# Not fleeing    1695
# Car             385
# Foot            294
# Other            96
# Name: flee, dtype: int64

# %%
sns.barplot(x=flee_freq.index, y=flee_freq);
